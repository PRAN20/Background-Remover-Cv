# %% [markdown]
# <a href="https://colab.research.google.com/github/PRAN20/Background-Remover-Cv/blob/main/Background_Remover.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Importing Header Files**

# %%
import numpy as np
import cv2

# %% [markdown]
# # **Importing Image**

# %%
imgo = cv2.imread("Image.jpg")
height, width = imgo.shape[:2]

# %%
height
# Out:
# 616

# %%
width
# Out:
# 1039

# %% [markdown]
# # **Create a Mask**

# %%
mask = np.zeros(imgo.shape[:2],np.uint8)

# %%
bgdModel = np.zeros((1,65),np.float64)
fgdModel = np.zeros((1,65),np.float64)

# %% [markdown]
# # **Making Rectangle**

# %%
rect = (10,10,width-30,height-30)
cv2.grabCut(imgo,mask,rect,bgdModel,fgdModel,5,cv2.GC_INIT_WITH_RECT)

# %%
import matplotlib.pyplot as plt
plt.imshow(imgo)
plt.show()

# %%
mask = np.where((mask==2)|(mask==0),0,1)

# %%
img1 = imgo*mask[:,:,np.newaxis]

# %%
background = imgo-img1

# %% [markdown]
# # **Change Pixels**

# %%
background[np.where((background > [0,0,0]).all(axis = 2))] = [255,255,255]

# %%
final = background + img1

# %%
plt.imshow(final)
plt.show()
